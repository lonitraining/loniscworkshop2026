# %% [markdown]
# <a href="https://colab.research.google.com/github/lonitraining/loniscworkshop2026/blob/main/day2/exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Day 2: Intermediate Python (Exercises)**
# ### **2026 LONI Scientific Computing Bootcamp**
#
# Dr. Jianxiong "Jason" Li
#
# jasonli3@lsu.edu
#
# Jun 2, 2026

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# # **❗Rules❗**
#
# * Complete each "**FIX ME**" in **one line**!
#   * *If you wrote more than one line, you are doing something wrong.*
# * Do **NOT** use a single loop!! Instead, use what we learned today.
#   * *If you wrote a single loop, you are doing something wrong.*

# %%
#@markdown **(Run me first to import numpy throughout this notebook)**
import numpy as np

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## **1. Write Your Own ReLU Function** (CS / Machine Learning)
#
# > * The purpose of this exercise is to practice the use of advanced indexing.

# %% [markdown]
# Rectified Linear Unit (ReLU) is a commonly used activation function in machine learning. The definition is simple:
#
# ![RELU Definition](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_1_ReLU.png)
#
# Here, you are asked to write your own ReLU funcion acting on a data array:
#
# * **Input**:
#   * An array of numbers (int or float).
# * **Function**:
#   * Changes all negative numbers in the input array to 0.
#   * Modifies the input array **in-place** (not returning a copy of the result).
#     * *Because you do not really need to know the result. "Activation funtions" are used to operate on the vectors before feeding to the next step.*

# %% [markdown]
# **❗CAUTION❗**
#
# * I did not say the input is 1-D array. Could be any arbitrary shape.
# * Don't do anything like this:
# ```
# for i in range(x.size):
#     if x[i]<0:
#       ...
# ```
# * **Hint**: Feel free to use any method to achieve it. Below I provided hints to two differnt methods using what we talked about today:
#   * **Method 1**: Keep in mind boolean array indexing is a reference.
#   * **Method 2**: When used in arithmatic calculation, boolean value `True` is treated as `1`, and `False` as `0`.

# %%
#@markdown **Define your own ReLU function**

# Your function here
def relu(x):
  # FIX ME


# Now test your function

# Create a random 5x5 matrix with positive and negative numbers
myAry = np.random.random([5, 5]) - 0.5
print("Input = \n", myAry)

# Apply your RELU function and see results
relu(myAry)
print("\nOutput = \n", myAry)

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## **2. Image Color Editing** (CS / Graphic Processing)
#
# > * The purpose of this exercise is to practice basic indexing, slicing, and reshaping to solve practical tasks.

# %% [markdown]
# In this exercise, we will edit the color of this picture:
#
# ![Space Racoon](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_2_racoon.png)
#
# Keep in mind that:
#
# * An single-color image is basically a **2-D matrix**, with each value being the intensity of each pixel.
# * An RBG colored image is basically **three** of such matrices combined, each one representing an image of a color channel.
#
# Once we understand that, we can import an image as a NumPy array, and edit it with array methods we learned today!

# %%
#@markdown ### **1) Import an RGB image**
#@markdown > *Nothing to fix. Just go over the code, and run it to see.*

# This part imports an image as a NumPy array
# Do not worry about these modules if you are not familiar
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
img = iio.imread('https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_2_racoon.png')
plt.imshow(img)
plt.show()

# What's in img?
print("\nThe type of img is:", type(img))
print("\nThe shape of img is:", img.shape)

# %% [markdown]
# > * *This is a `512 x 512` image, with the `3` on the last axis meaning three color channels.*

# %%
#@markdown ### **2) Show only the red channel**

# * For an RGB image:
#     - Red channel:    [:, :, 0]
#     - Green channel:  [:, :, 1]
#     - Blue channel:   [:, :, 2]
# * To show only the red channel, set other channels to 0

# Make a copy of original image
img_red = img.copy()

# Set green and blue channels to 0
# FIX ME

# Plot
plt.imshow(img_red)
plt.show()

# %%
#@markdown ### **3) Change color image to gray**

# * Gray color is when all 3 channels have the same value
# * Change the value of each channel at each pixel to the mean of all 3 channels

# Copy the image
img_gray = img.copy()

# Calculate a 512x512 array, with pixel's value being the average of all three channels
# Hint: You may need mean() or average()
img_mean = # FIX ME

# Give this averaged image to all 3 channels
# Hint: What are the shapes of "img_mean" and "img_gray"?
#       Can you just assign the values?
#       How do you assign properly?
img_gray[:,:,:] = # FIX ME

# Plot
plt.imshow(img_gray)
plt.show()

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## **3. One-Hot DNA Sequence Encoding** (Bioinformatics)
#
# > * The purpose of this exercise is to practice broadcasting in a practical research setup.

# %% [markdown]
# In bioinformatics, DNA sequences are represented as long strings of four distinct nucleotide characters: '**A**', '**C**', '**G**', and '**T**' (*Don't worry if you do not know whe thery are*). However, in practical research (such as machine learning), processing DNA sequences as raw texts is usually inefficient and confusing to computers.
#
# **One-Hot Encoding** addresses this challenge by representing each character as a unique, binary "hot" vector. The idea is to compare each character in a DNA sequence against a standard **`["A","C","G","T"]` alphabet**. For example, a character "A" would be encoded as the vector `[True, False, False, False]`, where only the index assigned to "A" is active. Therefore, the entire DNA sequence can be encoded to a 2-D boolean array.
#
# ![One-Hot DNA Encoding](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_3_one_hot_dna_encoding.jpg)
#
# Your goal in this practice, is to write a general function to encode an existing DNA sequence into such a "One-Hot" encoded matrix:
#
# * **Input**:
#   * A 1-D array made of `["A","C","G","T"]` alphabet (DNA sequence）.
#     * E.g., `np.array(["A", "T", "G", "C", "A", "G", "T", "A"])`
#     * Note the length is undetermined!
# * **Output**:
#   * A `N x 4` boolean array.
#     * The number of rows is the length of the input DNA sequence.
#     * The number of columns is always `4`, the total number of DNA alphabet.
#     * Each row is an encoded DNA character, with only one `True` and the rest `False`.

# %% [markdown]
# **❗CAUTION❗**
#
# * Don't do anything like this:
# ```
# for i in range(dna.size):
#     if dna[i] == "A":
#       ...
# ```
# * **Hint**:
#   * Comparison operator `==` also supports broadcasting!
#   * Pay attention to input / output shapes!
# * Bonus point if you can write your solution without obtaining the length of the input DNA sequence!

# %%
#@markdown **Define your One-Hot DNA encoding function**

# Your function here
def encode(dna):

  # DNA alphabet
  # Hint: Pay attention to its shape!
  alphabet = np.array(["A", "C", "G", "T"])

  # Your encoding
  dna_encoded = # FIX ME

  # Return results
  return(dna_encoded)


# Now test your function

# Create a test DNA sequence (Pay attention to its shape!)
my_dna = np.array(["A", "T", "G", "C", "A", "G", "T", "A"])

# Print the encoded DNA
print(encode(my_dna))

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## **Challenge: Wave Function Propagation of 1-D Harmonic Oscillator** (Physics)
#
# > * The purpose of this exercise it to practice various NumPy array creationg methods, ufuncs, and aggregation functions in a close-to-practical research problem.
# > * Don't worry if you do not work in physics! You can still finish the exercise even if you do not know the physics.

# %% [markdown]
# 1-D harmonic oscillator is one of the most fundamental dynamic systems in both classical and quantime-mechanical physics. It describes the dynamics of a particle inside a square potential `V(x) ∝ x^2`. In classical picture, it is just a mass attached to a spring oscillating back and forth. In quantum-mechanical picture, however, is a little more complicated.
#
# In quantum mechanics, a particle is not located in a fixed place, instead it has a **probability distribution** of where it may be found, which is defined by a **wave function**. In a quantum-mechanical picture, instead of the particle itself oscillating back and forth, it looks more like its probability distribution (a "wave packet", if you will) oscillating back and forth, but in the same way the mass does in the classical picture.
#
# ![P_4_scenario.png](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_4_scenario.png)
#
#
# Here, you are asked to write a simple code to study how the wave function of a 1-D harmonic oscillator propagates using quantum mechanical methods.

# %% [markdown]
# ### **1) Create the initial wave function on a discrete grid**

# %% [markdown]
# First create a 1-D array of `x` coordinates from `[-L/2, L/2]` (`L=10`), evenly spaced in `N=101` grid points. You will also need to find out step length `dx`.
#
# Then create the initial wave function on the above grid, which should look like:
#
# ![P_4_psi.png](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_4_psi.png)
#
# The `√C` is the normalization factor.

# %%
# Define parameters
N = 101       # Number of grid points
L = 10.0      # Length of the box

# Define the array x coordinates and obtrain step length dx
# Hint: You may need np.linspace() to create the array and return the step length
x, dx = # FIX ME

# Calculate the initial wave function
# For simplicity, first calculate without dividing by normalization factor "√C", then do the normalization
# Hint: You may need np.exp(), np.sqrt(), sum()
psi = # FIX ME
psi /= # FIX ME

# Plot probability distribution abs(psi)**2
import matplotlib.pyplot as plt
plt.plot(x, np.abs(psi)**2, label="Wave function")
plt.legend()
plt.show()

# %% [markdown]
# ### **2) Create the Hamiltonian matrix**

# %% [markdown]
# The Hamiltonian matrix is core of the dynamics in quantume mechanics. The Hamiltonian matrix is an `(N, N)` matrix (NumPy array), which can be defined this way:
#
# ![P_4_H.png](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_4_H.png)
#
# >* Matrix `T` (kinetic energy) is a tridiagonal Laplacian matrix (all diagonal elements are `-2` and off-diagonal elements are `1`) multiplied by a constant `-1/dx^2`.
# >* Matrix `V` (potential energy) is a diagonal matrix, with each element is the potential energy `V(x)=x^2/2` at the corresponding coordinate. All other unwritten elements are `0`.

# %%
# Create matrix T
# Hint: You may need np.diag(), np.identity(), or np.eye().
T = # FIX ME

# Create matrix V
# Hint: You may need np.diag()
V = # FIX ME

# Create Hamiltonian matrix H
H = # FIX ME

# Print Hamiltonian matrix
print("The Hamiltonian matrix is:\n", H)

# %% [markdown]
# ### **3) Build the propagator**

# %% [markdown]
# Now we are getting somewhere likely known only to physicists! You can proudly tell your friends that you did some actual physics research!
#
# Based on the Hamiltonian matrix, we will now build the propagator, which is a matrix you actually multiple to the left of the wave function. The propagator is defined like this:
#
# ![P_4_CN.png](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_4_CN.png)
#
# Where `I` is the `(N, N)` identity matrix, `i` is the imaginary unit, and `dt` is the time step length. Here we will let time goes from `0` to `4*pi`, and a total of `Nt=20,000` steps, so that step length is short enough. Notice that there is a matrix inverse and a matrix multiplications!
#
# > * This method is known as **Crank-Nicholson method**, the most commonly used numerical method to propagate wave function.
# > * The reason we form the propagator this way, instead of directly using `H`, is to preserve normalization of the wave function.

# %%
# Define parameters
tmin = 0
tmax = 4*np.pi
Nt = 20000

# Define time coordinates and return time step length dt
# Hint: You may np.linspace() to create the array and return the time step
t, dt = # FIX ME
print("Time step length is:", dt)

# Create the propagator
# Hint: You may need:
#     np.linalg.inv(A)  : Matrix inverse
#     np.dot(A,B)       : Matrix multiplication
#     1j                : Imaginary unit
U = # FIX ME

# Print the propagator
print("Propagator is:\n", U)

# Look, your propagator should be close to an identity matrix
# Do not believe it? Let's calculate its "trace" (the sum of all diagnoal elements). It should be very close to N.
print("\nTrace of propagator is:", np.trace(U))

# %% [markdown]
# ### **4) Let's see the results!**

# %% [markdown]
# Now let's see the results! This part is not very related to NumPy, so I will not ask you to write or understand. But if you have done correctly in previous steps, just run this part and you should see a nice animation of wave packet oscillating back and forth like a classical particle. If it is messed up, check previous steps again.

# %%
#@markdown **(Just run me. I promise I will do no harm)**

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Change psi to complex number
psi = psi.astype("complex")

# Create a figure and axes
fig, ax = plt.subplots()

# Set the x and y axis of the plot
ax.set_xlim(-L/2, L/2)
ax.set_ylim(0, 1)

# Initialize an empty line object
ax.plot(x, x**2/20, "--")
line, = ax.plot([], [])

# Define the animation update function
nframe = 100
def update(frame):

    # Generate y values based on the frame number
    global psi
    global nframe
    for index in range(int(Nt/nframe)):
      psi = np.dot(U, psi)

    # Update the line data
    line.set_data(x, np.abs(psi)**2)

    return line,

# Create the animation
animation = FuncAnimation(fig, update, frames=nframe, interval=50, blit=True)

#animation.save("P_4_result.gif")
from IPython.display import HTML
HTML(animation.to_jshtml())

# %% [markdown]
# If you are doing it correctly, you should get something like this:
# ![P_4_result.gif](https://github.com/lonitraining/loniscworkshop2026/raw/main/day2/images/P_4_result.gif)

# %% [markdown]
# Now, congratulations! You just did some physics research!
#
# FYI, what you just did is actually solving the most fundamental equation in quantum mechanics: **Time-Dependent Schrodinger's Equation** (**TDSE**). TDSE governs the quantum-mechanical dynamics of the microscopic particles. In actual research, physicists usually propagate TDSE like this to see how wave function evolve in time to extract useful information. And TDSE results are sometimes regarded as the **exact** results, pretty much equivalent to what you would get in experiments.
#
# But actual research problems could be much more complicated and costly. They may need larger grid, 3-D instead of 1-D, spherical coordinates, multiple particles, different physics models, etc..
