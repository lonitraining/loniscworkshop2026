# %% [markdown]
# <a href="https://colab.research.google.com/github/lonitraining/loniscworkshop2026/blob/main/day2/0_coding_in_the_era_of_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Day 2: Intermediate Python**
# ### **2026 LONI Scientific Computing Bootcamp**
#
# Dr. Jianxiong "Jason" Li
#
# jasonli3@lsu.edu
#
# Jun 2, 2026

# %% [markdown]
# <br><br>
#
# ---
# # **Prologue: Coding in the Era of AI**
# ---

# %% [markdown]
# <br>
#
# ## **1) Why still bother learning to code when AIs can write an entire app for me within hours?**

# %% [markdown]
# ### **Scenario 1: Coding ≠ Software Engineering**

# %% [markdown]
# ![scene1](https://raw.githubusercontent.com/lonitraining/loniscworkshop2026/refs/heads/main/day2/images/0_1.jpg)
#
# Coding is just the **tip of the iceberg** of software engineering.
# *   System Design & Architecture
# *   Collaboration & Communication
# *   Testing & Quality Control
# *   Infrastructure
# *   Maintenance & Debugging
# *   User services
# *   Licensing & Legal Compliance
# *   ...

# %% [markdown]
# ### **Scenario 2: Lowering the bar isn't always good**

# %% [markdown]
# ![scene1](https://raw.githubusercontent.com/lonitraining/loniscworkshop2026/refs/heads/main/day2/images/0_2.jpg)
#
# Anyone can write code with the help of AI. What makes you special?
#
# * Maybe, it's your understanding of the code

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## **2) Working with AI in this course**

# %% [markdown]
# ### **a) In this course, we will spend...**

# %% [markdown]
# *  Less time on **basic syntax**
#     *   *Entry-level coding become less relavent with AI...*
# *  More time on **key concepts** that will help you in your future scientific computation.
#     *   *Understanding key concepts helps you direct AI more efficiently*

# %% [markdown]
# ### **b) You are encouraged to use AI to assist you...**

# %% [markdown]
# *   **Method 1**: Ask any AI tool of your preference
# *   **Method 2**: Click on the "**Toggle Gemini**" in the bottom of the page to use Gemini
#     * Integrated with Google Colab
#     * Select a cell and ask questions

# %% [markdown]
# #### **Example 1**
# Writing code with AI:

# %%
# Ask AI to write a simple bubble sort function in Python

def bubble_sort(arr):
    # FIX ME

# %% [markdown]
# #### **Example 2**
#
# Asking AI to explain code or debug:

# %%
# Ask AI to explain what is wrong with below code:

list1 = [1, 2, 3]
list2 = list1
list2[0] = 4
print("list2 : ", list2)      # We changed list2, of course
print("list1 : ", list1)      # Why is list1 also changed?

# %% [markdown]
# ### ***Disclaimer***

# %% [markdown]
# *The AI tools demonstrated today are third‑party platforms and are not sponsored, endorsed, or provided by LSU.
# Students may choose to explore these tools on their own, but should follow LSU policies and course‑specific rules regarding AI use.*

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## **3) Today's topic**

# %% [markdown]
# ### **a) Outlines**

# %% [markdown]
# We are just going to talk about one Python module: **NumPy**

# %% [markdown]
# > **1. A Glimpse at NumPy**
# >
# > **2. Creating Special Matrices**
# >
# > **3. Manipulating Shape**
# >
# > **4. Faster with Numpy**
# >
# > **6. Exercises**

# %% [markdown]
# ### **b) Goal**

# %% [markdown]
# Learn a few simple and important NumPy tricks to **significantly boost your code efficiency** for your research!
#
# > *Keep in mind, some of them can make your code faster by **two orders of magnitudes**!*
